# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#les données
Os_prix = [400,240,500,230,200]
Mac_prix = [300,230,430,200,180]
Android_prix = [120,300,140,290,190]
Annee=[2012,2015,2020,2021,2022]

# %%
index_annee= np.arange(len(Annee))
a = 0.25
plt.bar(index_annee,Os_prix,label='Prix windows',width=0.25)
plt.bar(index_annee + a,Mac_prix,label='Prix Apple',width=0.25)
#plt.plot(Année,Android_prix,label='Prix_SP ',color='lime')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Prix des P.C')
plt.title('Evolution des ordinateurs');

# %%
plt.subplot(2,1,1)
plt.bar(Année,Os_prix,label='Prix windows',color='cyan')
#plt.scatter(Année,Mac_prix,label='Prix Apple',color='khaki')
#plt.plot(Année,Android_prix,label='Prix_SP ',color='lime')
plt.legend()
#plt.xlabel('Année')
plt.ylabel('Prix des P.C')
plt.title('Evolution des ordinateurs')

plt.subplot(2,1,2)
#plt.bar(Année,Os_prix,label='Prix windows',color='yellow')
plt.scatter(Année,Mac_prix,label='Prix Apple',color='yellow')
#plt.plot(Année,Android_prix,label='Prix_SP ',color='lime')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Prix des P.C');
#plt.title('Evolution des ordinateurs')

# %%
#dessin de pie
produit=['P1','P2','P3']
vente=[20,40,50]
plt.pie(vente,labels=produit,autopct='%1.1f%%')
