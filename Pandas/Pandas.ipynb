# %%
#importation de pandas
import pandas as pd

# %%
#Connaissance de base sur les données avec DataFrame
d=pd.DataFrame({'Homme':[23,34],'Femme':[34,65]})
i=pd.DataFrame({'Bon':['fouss','baba'],'bad':['zak','fass']})
A=pd.DataFrame({'Animal':['Lion','Tigre'],'Plante':['Mafe','Tournesol']},index=['A','B'])

# %%
#Connaissance de base sur les series 
s=pd.Series([1,2,3,4,5])
A1=pd.Series([1200,3400,2400],index=['Stats-2012','Stats-2015','Stats-2022'], name='Statistique')
#print (A1)

# %%
#Introduction

stats = pd.read_csv('covid.csv')
stats.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
#Accesseurs

stats.Population
stats['Continent']
stats['Continent'][1]
# Out:
# 'South America'

# %%
#Les Indexations Pandas

stats.iloc[2]
stats.iloc[:,2]
stats.iloc[:1,0]
stats.iloc[1:4,0]
stats.iloc[[0,1,2],0]
stats.iloc[:-208]
stats.head()
stats.loc[-1:1,['Continent','Population']]
stats.loc[:,['Continent','Population']]
# Out:
#          Continent    Population
# 0    North America  3.311981e+08
# 1    South America  2.127107e+08
# 2             Asia  1.381345e+09
# 3           Europe  1.459409e+08
# 4           Africa  5.938157e+07
# ..             ...           ...
# 204  North America  4.992000e+03
# 205  North America  2.624700e+04
# 206  South America  3.489000e+03
# 207         Europe  8.010000e+02
# 208         Africa  5.986820e+05
#
# [209 rows x 2 columns]

# %%
#Manipulation des données indexées

stats.set_index('Continent')
# Out:
#                       Country/Region    Population  TotalCases  NewCases  \
# Continent
# North America                    USA  3.311981e+08     5032179       NaN
# South America                 Brazil  2.127107e+08     2917562       NaN
# Asia                           India  1.381345e+09     2025409       NaN
# Europe                        Russia  1.459409e+08      871894       NaN
# Africa                  South Africa  5.938157e+07      538184       NaN
# ...                              ...           ...         ...       ...
# North America             Montserrat  4.992000e+03          13       NaN
# North America  Caribbean Netherlands  2.624700e+04          13       NaN
# South America       Falkland Islands  3.489000e+03          13       NaN
# Europe                  Vatican City  8.010000e+02          12       NaN
# Africa                Western Sahara  5.986820e+05          10       NaN
#
#                TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  \
# ...

# %%
#Implémentation des conditions

stats.Continent== 'Africa'
stats.loc[stats.Continent=='Africa']
stats.loc[(stats.Continent=='Africa') & (stats.Population>= 60000000)]
stats.loc[stats.Continent.isin(['Africa','Asia'])  & (stats.Population>= 160000000)]
stats.loc[stats.Continent.isin(['Africa','Asia']) & stats.Continent=='NaN']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 204    False
# 205    False
# 206    False
# 207    False
# 208     True
# Name: Continent, Length: 209, dtype: bool

# %%
#Affectations des données 

stats['NewCases']= 20
stats['NewCases']
stats['NewCases']= range(len(stats),0,-1)
stats['NewCases']
stats.head()

# %%
#Function
stats= pd.read_csv('covid.csv')
stats.head()
stats.Continent.describe()
stats.Population.describe()
# Out:
# count    2.080000e+02
# mean     3.041549e+07
# std      1.047661e+08
# min      8.010000e+02
# 25%      9.663140e+05
# 50%      7.041972e+06
# 75%      2.575614e+07
# max      1.381345e+09
# Name: Population, dtype: float64
